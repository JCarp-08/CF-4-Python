# %% [markdown]
# # 01. Import Libraries

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # 02. Import Data

# %%
df_cus = pd.read_csv(r'C:\Users\jmanc\OneDrive\Desktop\InstaCart Basket Analysis\02 Data\Original Data\customers.csv')

# %% [markdown]
# # 03. Data Clean and Initial Consistancy Check

# %%
df_cus.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 206209 entries, 0 to 206208
# Data columns (total 10 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   user_id       206209 non-null  int64
#  1   First Name    194950 non-null  object
#  2   Surnam        206209 non-null  object
#  3   Gender        206209 non-null  object
#  4   STATE         206209 non-null  object
#  5   Age           206209 non-null  int64
#  6   date_joined   206209 non-null  object
#  7   n_dependants  206209 non-null  int64
#  8   fam_status    206209 non-null  object
#  9   income        206209 non-null  int64
# dtypes: int64(4), object(6)
# memory usage: 15.7+ MB

# %%
df_cus = df_cus.dropna(subset = ['user_id'], axis = 0)

# %%
df_cus.head()
# Out:
#    user_id First Name    Surnam  Gender       STATE  Age date_joined  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    n_dependants fam_status  income
# 0             3    married  165665
# 1             0     single   59285
# 2             2    married   99568
# 3             0     single   42049
# 4             1    married   40374

# %%
df_cus = df_cus.drop(columns = ['First Name','Surnam']) #dropping columns for PII compliance.

# %%
df_cus.head()
# Out:
#    user_id  Gender       STATE  Age date_joined  n_dependants fam_status  \
# 0    26711  Female    Missouri   48    1/1/2017             3    married
# 1    33890  Female  New Mexico   36    1/1/2017             0     single
# 2    65803    Male       Idaho   35    1/1/2017             2    married
# 3   125935  Female        Iowa   40    1/1/2017             0     single
# 4   130797  Female    Maryland   26    1/1/2017             1    married
#
#    income
# 0  165665
# 1   59285
# 2   99568
# 3   42049
# 4   40374

# %%
df_cus.rename(columns = {'STATE' : 'state'}, inplace = True)
df_cus.rename(columns = {'n_dependants' : 'dependants'}, inplace = True)
df_cus.head()
# Out:
#    user_id  Gender       state  Age date_joined  dependants fam_status  income
# 0    26711  Female    Missouri   48    1/1/2017           3    married  165665
# 1    33890  Female  New Mexico   36    1/1/2017           0     single   59285
# 2    65803    Male       Idaho   35    1/1/2017           2    married   99568
# 3   125935  Female        Iowa   40    1/1/2017           0     single   42049
# 4   130797  Female    Maryland   26    1/1/2017           1    married   40374

# %%
df_cus['state'].value_counts()
# Out:
# Florida                 4044
# Colorado                4044
# Illinois                4044
# Alabama                 4044
# District of Columbia    4044
# Hawaii                  4044
# Arizona                 4044
# Connecticut             4044
# California              4044
# Indiana                 4044
# Arkansas                4044
# Alaska                  4044
# Delaware                4044
# Iowa                    4044
# Idaho                   4044
# Georgia                 4044
# Wyoming                 4043
# Mississippi             4043
# Oklahoma                4043
# Utah                    4043
# New Hampshire           4043
# Kentucky                4043
# Maryland                4043
# Rhode Island            4043
# Massachusetts           4043
# Michigan                4043
# New Jersey              4043
# Kansas                  4043
# South Dakota            4043
# Minnesota               4043
# Tennessee               4043
# New York                4043
# ...

# %%
df_cus['Gender'].value_counts()
# Out:
# Male      104067
# Female    102142
# Name: Gender, dtype: int64

# %%
df_cus['fam_status'].value_counts()
# Out:
# married                             144906
# single                               33962
# divorced/widowed                     17640
# living with parents and siblings      9701
# Name: fam_status, dtype: int64

# %%
df_cus.shape
# Out:
# (206209, 8)

# %%
df_cus = df_cus.drop_duplicates()

# %%
df_cus.shape
# Out:
# (206209, 8)

# %%
df_cus.describe()
# Out:
#              user_id            Age     dependants         income
# count  206209.000000  206209.000000  206209.000000  206209.000000
# mean   103105.000000      49.501646       1.499823   94632.852548
# std     59527.555167      18.480962       1.118433   42473.786988
# min         1.000000      18.000000       0.000000   25903.000000
# 25%     51553.000000      33.000000       0.000000   59874.000000
# 50%    103105.000000      49.000000       1.000000   93547.000000
# 75%    154657.000000      66.000000       3.000000  124244.000000
# max    206209.000000      81.000000       3.000000  593901.000000

# %% [markdown]
# # 04. Export Cleaned Set Before Merge

# %%
df_cus.to_pickle(r'C:\Users\jmanc\OneDrive\Desktop\InstaCart Basket Analysis\02 Data\Prepared Data\customers_clean')

# %% [markdown]
# # 05. Import Large Data Frame for Merger

# %%
df_full = pd.read_pickle(r'C:\Users\jmanc\OneDrive\Desktop\InstaCart Basket Analysis\02 Data\Prepared Data\ICB_full_merge.pkl')

# %% [markdown]
# # 06. Merge on User_ID

# %%
df_full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32435059 entries, 0 to 32435058
# Data columns (total 20 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   order_id                float64
#  1   user_id                 float64
#  2   order_number            float64
#  3   orders_day_of_week      float64
#  4   hour_of_order           float64
#  5   days_since_prior_order  float64
#  6   product_id              int64
#  7   add_to_cart_order       float64
#  8   reordered               float64
#  9   product_name            object
#  10  aisle_id                float64
#  11  department_id           float64
#  12  prices                  float64
#  13  _merge                  category
#  14  max_order               float64
#  15  loyalty_flag            object
#  16  mean_price              float64
#  17  spending_flag           object
#  18  med_dspo                float64
#  19  frequent_shopper        object
# ...

# %%
df_full = df_full.drop(columns = ['_merge'])

# %%
df_full.head()
# Out:
#     order_id  user_id  order_number  orders_day_of_week  hour_of_order  \
# 0  2539329.0      1.0           1.0                 2.0            8.0
# 1  2398795.0      1.0           2.0                 3.0            7.0
# 2   473747.0      1.0           3.0                 3.0           12.0
# 3  2254736.0      1.0           4.0                 4.0            7.0
# 4   431534.0      1.0           5.0                 4.0           15.0
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                1.0        0.0
# 1                    15.0         196                1.0        1.0
# 2                    21.0         196                1.0        1.0
# 3                    29.0         196                1.0        1.0
# 4                    28.0         196                1.0        1.0
#
#   product_name  aisle_id  department_id  prices  max_order  loyalty_flag  \
# ...

# %%
df_merge = df_full.merge(df_cus, on = 'user_id', indicator = True)

# %% [markdown]
# # 07. Consistency Check

# %%
df_merge['_merge'].value_counts()
# Out:
# both          32435059
# left_only            0
# right_only           0
# Name: _merge, dtype: int64

# %%
df_merge.head()
# Out:
#     order_id  user_id  order_number  orders_day_of_week  hour_of_order  \
# 0  2539329.0      1.0           1.0                 2.0            8.0
# 1  2398795.0      1.0           2.0                 3.0            7.0
# 2   473747.0      1.0           3.0                 3.0           12.0
# 3  2254736.0      1.0           4.0                 4.0            7.0
# 4   431534.0      1.0           5.0                 4.0           15.0
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                1.0        0.0
# 1                    15.0         196                1.0        1.0
# 2                    21.0         196                1.0        1.0
# 3                    29.0         196                1.0        1.0
# 4                    28.0         196                1.0        1.0
#
#   product_name  ...  med_dspo  frequent_shopper  Gender    state Age  \
# ...

# %%
df_merge.describe()
# Out:
#            order_id       user_id  order_number  orders_day_of_week  \
# count  3.243506e+07  3.243506e+07  3.243506e+07        3.243506e+07
# mean   1.710748e+06  1.029372e+05  1.714195e+01        2.738815e+00
# std    9.873006e+05  5.946651e+04  1.753496e+01        2.090051e+00
# min    2.000000e+00  1.000000e+00  1.000000e+00        0.000000e+00
# 25%    8.559430e+05  5.142000e+04  5.000000e+00        1.000000e+00
# 50%    1.711047e+06  1.026110e+05  1.100000e+01        3.000000e+00
# 75%    2.565514e+06  1.543910e+05  2.400000e+01        5.000000e+00
# max    3.421083e+06  2.062090e+05  9.900000e+01        6.000000e+00
#
#        hour_of_order  days_since_prior_order    product_id  add_to_cart_order  \
# count   3.243506e+07            3.035696e+07  3.243506e+07       3.243506e+07
# mean    1.342498e+01            1.110414e+01  2.557635e+04       8.351081e+00
# std     4.246357e+00            8.778941e+00  1.409657e+04       7.126656e+00
# ...

# %%
df_merge.isnull().sum()
# Out:
# order_id                        0
# user_id                         0
# order_number                    0
# orders_day_of_week              0
# hour_of_order                   0
# days_since_prior_order    2078102
# product_id                      0
# add_to_cart_order               0
# reordered                       0
# product_name                30200
# aisle_id                    30200
# department_id               30200
# prices                      30200
# max_order                       0
# loyalty_flag                    0
# mean_price                      0
# spending_flag                   0
# med_dspo                        0
# frequent_shopper                0
# Gender                          0
# state                           0
# Age                             0
# date_joined                     0
# dependants                      0
# fam_status                      0
# income                          0
# _merge                          0
# dtype: int64

# %% [markdown]
# # 08. Export

# %%
df_merge.to_pickle(r'C:\Users\jmanc\OneDrive\Desktop\InstaCart Basket Analysis\02 Data\Prepared Data\ICB_full_merge.pkl')
